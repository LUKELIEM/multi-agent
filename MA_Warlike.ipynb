# %% [markdown]
# # Culture Optimization - Warlike
#
# Teams with Warlike culture require longer training episodes, so a separate notebook is used specifically for this.

# %%
import os
import random
import time
import platform
import torch
import gym
import numpy as np

# This is the Gathering Game Environment based on Tribal Organization of agents
from tribes_env import GatheringEnv
from tribes_model import *

import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

print("Python version: ", platform.python_version())
print("Pytorch version: {}".format(torch.__version__))
print("OpenAI Gym version: {}".format(gym.__version__))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Python version:  3.6.4
# Pytorch version: 0.4.1.post2
# OpenAI Gym version: 0.9.2

# %% [markdown]
# ## Culture = Warlike
#
# Run finish_episode() specific to this culture.

# %%
def finish_episode(learners, optimizers, gamma, cuda):
    """ 
    Note that in RL, policy gradient is calculated at the end of an episode and only then used to 
    update the weights of an agent's policy. This is very different compared to image recog.
    
    The code will perform policy update on each learning agent independently. Reward for each time 
    step is stored in the list policy.rewards[] --> r(t)
    """  
    
    num_learners = len(learners)
    total_norms = [0 for i in range(num_learners)]
    policy_losses = [[] for i in range(num_learners)]
    losses = [[] for i in range(num_learners)]
    T_reward = []

   
    for i in range(num_learners):

        R = 0
        saved_actions = learners[i].saved_actions
        
        for t in tribes:
            if t.name is learners[i].tribe:
                T_reward = t.tribal_awards(US_hits = learners[i].US_hits,THEM_hits = learners[i].THEM_hits)
 
                # For debug only
                # print('Agent{} receives tribal award from Tribe{}'.format(i,t.name))
                # print (T_reward)
                # print (learners[i].rewards)
                
        # Do not implement actor-critic for now
        # value_losses = []
        
        rewards = deque()

        for r,T in zip(learners[i].rewards[::-1],T_reward[::-1]):
            # The agent is incentivized to cooperate by an award of 30% of what the tribe takes
            # in by all its members
            R = r + T + gamma * R
            rewards.appendleft(R)
            
        rewards = list(rewards)
        rewards = torch.Tensor(rewards)
        if cuda:
            rewards = rewards.cuda()

        # z-score rewards
        rewards = (rewards - rewards.mean()) / (1.1e-7+rewards.std())
        
        #Debug     
        #print (rewards)       
        
        """
        Do not implement actor-critic for now!!!
        for (log_prob, state_value), r in zip(saved_actions, rewards):
            reward = r - state_value.data[0]
            policy_losses.append(-log_prob * Variable(reward))
            r = torch.Tensor([r])
            if cuda:
                r = r.cuda()
            value_losses.append(torch.nn.functional.smooth_l1_loss(state_value,
                                                               Variable(r)))

        optimizer.zero_grad()
        loss = torch.stack(policy_losses).sum() + torch.stack(value_losses).sum()
        loss.backward()        
        
        
        """
        for log_prob, r in zip(saved_actions, rewards):
            r = torch.Tensor([r])
            if cuda:
                r = r.cuda()
            policy_losses[i].append(-log_prob * Variable(r))

        optimizers[i].zero_grad()
        losses[i] = torch.stack(policy_losses[i]).sum()
        losses[i].backward()
        
        # Gradient Clipping Update: prevent exploding gradient
        total_norms[i] = torch.nn.utils.clip_grad_norm_(learners[i].parameters(), 8000)
        
        optimizers[i].step()
        learners[i].clear_history()   # clear an agent's history at the end of episode


    return total_norms

# %% [markdown]
# ## Special Case - Warlike Culture
#
# We discovered that if we run training of only 300 game steps, the agents with Warlike culture will spend the 1st hundreds of steps in mutually assured destruction - a field of deadly crossfire which they cannot escape out of.
#
# So we lengthen the game step to 1000 instead.

# %%
import gym
import sys
import pickle
from collections import deque

import torch
import torch.optim as optim
from torch.autograd import Variable
import numpy as np

# Initialize agents parameters
#   9 agents - 8 learning agents, 0 trained agents, 1 random agents
num_learners = 8
num_trained = 0
num_rdn = 1
num_statics = num_trained + num_rdn
num_agents = num_learners + num_statics  

# Initialize environment
game = "Gather"
num_actions = 8                       # 8 actions in Gathering

# Initialize training parameters
warm_start = False
num_frames = 4      # environ observation consists of a list of 4 stacked frames per agent
max_episodes = 5000
max_frames = 1000
max_frames_ep = 0   # track highest number of frames an episode can last

# These trainer parameters works for Atari Breakout
gamma = 0.99  
lr = 1e-3
temp_start = 1.8  # Temperature for explore/exploit
temp_end = 1.0
log_interval = 100
save_interval = 500


def unpack_env_obs(env_obs):
    """
    Gathering is a partially-observable Markov Game. env_obs returned by GatheringEnv is a numpy 
    array of dimension (num_agent, 800), which represents the agents' observations of the game.

    The 800 elements (view_box) encodes 4 layers of 10x20 pixels frames in the format:
    (viewbox_width, viewbox_depth, 4).
    
    This code reshapes the above into stacked frames that can be accepted by the Policy class:
    (batch_idx, in_channel, width, height)
    
    """
    
    num_agents = len(env_obs)  # environ observations is a list of agents' observations
    
    obs = []
    for i in range(num_agents):
        x = env_obs[i]   # take the indexed agent's observation
        x = torch.Tensor(x)   # Convert to tensor
        
        # Policy is a 3-layer CNN
        x = x.view(1, 10, 20, -1)  # reshape into environment defined stacked frames
        x = x.permute(0, 3, 1, 2)  # permute to Policy accepted stacked frames
        obs.append(x)
        
    return obs  # return a list of Tensors


"""
For now, we do not implement LSTM            
# LSTM Change: Need to cycle hx and cx thru function
def select_action(model, state, lstm_hc, cuda):
    hx , cx = lstm_hc 
    num_frames, height, width = state.shape
    state = torch.FloatTensor(state.reshape(-1, num_frames, height, width))

    if cuda:
        state = state.cuda()

    probs, value, (hx, cx) = model((Variable(state), (hx, cx)))

    m = torch.distributions.Categorical(probs)
    action = m.sample()
    log_prob = m.log_prob(action)
    # LSTM Change: Need to cycle hx and cx thru function
    return action.data[0], log_prob, value, (hx, cx)
"""


def select_learner_action(model, obs, cuda):
    """
    This code expects obs to be an array of stacked frames of the following dim:
    (batch_idx, in_channel, width, height)
    
    This is inputted into model - the agent's Policy, which outputs a probability 
    distribution over available actions.
    
    Policy gradient is implemented using torch.distributions.Categorical. 
    """
    
    # Policy is a 3-layer CNN
    # _, num_frames, width, height = obs.shape
    # obs = torch.FloatTensor(obs.reshape(-1, num_frames, width, height))
    
    # Policy is a 2-layer NN for now
    # obs = obs.view(1, -1)
   
    if cuda:
        obs = obs.cuda()
      
    probs = model(obs)
    m = torch.distributions.Categorical(probs)
    action = m.sample()
    log_prob = m.log_prob(action)

    return action.item(), log_prob 


def load_info(agents, narrate=False):
    for i in range(num_agents):    
        agents[i].load_info(info[i])
        if narrate:
            if agents[i].tagged:
                print('frame {}, agent{} is tagged'.format(frame,i))
            if agents[i].laser_fired:
                print('frame {}, agent{} fires its laser'.format(frame,i))
                print('and hit {} US and {} THEM'.format(agents[i].US_hit, agents[i].THEM_hit))
    return


# The main code starts here!!!

cultures =[{'name':'warlike', 'penalty':-1.0, 'reward':0.005},
           {'name':'warlike', 'penalty':-1.0, 'reward':0.01},
           {'name':'warlike', 'penalty':-1.0, 'reward':0.05}
          ]
# Cultural parameter search
"""
cultures =[{'name':'warlike', 'penalty':-1.0, 'reward':0.001},
           {'name':'warlike', 'penalty':-1.0, 'reward':0.005},
           {'name':'warlike', 'penalty':-1.0, 'reward':0.01},
           {'name':'warlike', 'penalty':-1.0, 'reward':0.05},
           {'name':'warlike', 'penalty':-1.0, 'reward':0.1},
           {'name':'warlike', 'penalty':-1.0, 'reward':0.5},
           {'name':'warlike', 'penalty':-1.0, 'reward':1.0}
          ]
"""


for culture in cultures:   # Go down the list of cultures

    # Data structure for agents
    agents = []
    actions = []
    log_probs = []
    tags = []
    rewards = []
    optimizers = []

    # Cold start
    if warm_start is False:
   
        # Initialize learner agents, then load static agents (trained followed by random)
        for i in range(num_learners):
            print("Learner agent {}".format(i))
            agents.append(Policy(num_frames, num_actions, i)) # No weights loaded for learning agent
            optimizers.append(optim.Adam(agents[i].parameters(), lr=lr))
        
            # set up optimizer - this works for Atari Breakout
            # optimizers.append(optim.RMSprop(agents[i].parameters(), lr=lr, weight_decay=0.1)) 
        
        for i in range(num_learners, num_learners+num_trained):
            print ("No trained agent exist yet!")
            raise
            """
            Disable for now! No trained model exist!!!
            agents.append(Policy(num_frames, num_actions, i))
            agents[i].load_weights()         # load weight for static agent        
            """
        for i in range(num_learners+num_trained, num_agents):
            print("Load random agent {}".format(i))
            agents.append(Rdn_Policy())

    
        # Initialize all agent data
        actions = [0 for i in range(num_agents)]
        log_probs = [0 for i in range(num_agents)]
        tags = [0 for i in range(num_agents)]
        rewards = [0 for i in range(num_agents)]

        # Keep track of rewards learned by learners
        episode_reward = [0 for i in range(num_learners)]   # reward for an episode
        running_reward = [None for i in range(num_learners)]   # running average
        running_rewards = [[] for i in range(num_learners)]   # history of running averages
        best_reward = [0 for i in range(num_learners)]    # best running average (for storing best_model)

        # This is to support warm start for training
        prior_eps = 0

    # Warm start
    if warm_start:
        print ("Cannot warm start")
        raise
    
        """
        # Disable for now!  Need to ensure model can support training on GPU and game playing
        # on both CPU and GPU.
    
        data_file = 'results/{}.p'.format(game)

        try:
            with open(data_file, 'rb') as f:
                running_rewards = pickle.load(f)
                running_reward = running_rewards[-1]

            prior_eps = len(running_rewards)

            model_file = 'saved_models/actor_critic_{}_ep_{}.p'.format(game, prior_eps)
            with open(model_file, 'rb') as f:
                # Model Save and Load Update: Include both model and optim parameters
                saved_model = pickle.load(f)
                model, optimizer = saved_model

        except OSError:
            print('Saved file not found. Creating new cold start model.')
            model = Policy(input_channels=num_frames, num_actions=num_actions)
            optimizer = optim.RMSprop(model.parameters(), lr=lr,
                                      weight_decay=0.1)
            running_rewards = []
            prior_eps = 0
        """

    # Establish tribal association
    tribes = []
    tribes.append(Tribe(name='Vikings',color='blue', culture=culture, \
                    agents=[agents[0], agents[1], agents[2]]))
    tribes.append(Tribe(name='Saxons', color='red', culture=culture, \
                    agents=[agents[3], agents[4]]))
    tribes.append(Tribe(name='Franks', color='purple', culture=culture, \
                    agents=[agents[5], agents[6], agents[7]]))
    tribes.append(Tribe(name='Crazies', color='yellow', agents=[agents[8]]))   # random agents are crazy!!!

    # 9 agents in 4 tribes, used map defined in default.txt
    agent_colors = [agent.color for agent in agents]
    agent_tribes = [agent.tribe for agent in agents]
    env = GatheringEnv(n_agents=num_agents,agent_colors=agent_colors, agent_tribes=agent_tribes, \
                       map_name='default')    
   
    
    cuda = torch.cuda.is_available()

    if cuda:
        for i in range(num_learners):    # Learning agents need to utilize GPU
            agents[i].cuda()

        
    for ep in range(max_episodes):
    
        print('.', end='')  # To show progress
    
        # Anneal temperature from temp_start to temp_end
        for i in range(num_learners):    # For learning agents
            agents[i].temperature = max(temp_end, temp_start - (temp_start - temp_end) * (ep / max_episodes))

        env_obs = env.reset()  # Env return observations

        # For Debug only
        # print (len(env_obs))
        # print (env_obs[0].shape)
    
        # Unpack observations into data structure compatible with agent Policy
        agents_obs = unpack_env_obs(env_obs)

        for i in range(num_learners):    # Reset agent info - laser tag statistics
            agents[i].reset_info()   

        # For Debug only
        # print (len(agents_obs))
        # print (agents_obs[0].shape)
    
        """
        For now, we do not stack observations, and we do not implement LSTM
    
        state = np.stack([state]*num_frames)

        # LSTM change - reset LSTM hidden units when episode begins
        cx = Variable(torch.zeros(1, 256))
        hx = Variable(torch.zeros(1, 256))
        if cuda:
            cx = cx.cuda()
            hx = hx.cuda()
        """

        episode_reward = [0 for i in range(num_learners)]   # reward for an episode
    
        for frame in range(max_frames):

            """
            For now, we do not implement LSTM
            # Select action
            # LSTM Change: Need to cycle hx and cx thru select_action
            action, log_prob, value, (hx,cx)  = select_action(model, state, (hx,cx), cuda)        
            """

            for i in range(num_learners):    # For learning agents
                actions[i], log_probs[i] = select_learner_action(agents[i], agents_obs[i], cuda)
                if actions[i] is 6:
                    tags[i] += 1   # record a tag for accessing aggressiveness
                agents[i].saved_actions.append((log_probs[i]))
            
                # Do not implement LSTM for now
                # actions[i].saved_actions.append((log_prob, value))
            
            for i in range(num_learners, num_learners+num_trained):
                print ("No trained agent exist yet!")
                raise
            for i in range(num_learners+num_trained, num_agents):   # For random agents
                actions[i] = agents[i].select_action(agents_obs[i])
                if actions[i] is 6:
                    tags[i] += 1   # record a tag for accessing aggressiveness

            # For Debug only
            # if frame % 20 == 0:
            #    print (actions) 
            #    print (log_probs)
            
            # Perform step        
            env_obs, reward, done, info = env.step(actions)
        
            """
            For Debug only
            print (env_obs)
            print (reward)
            print (done) 
            """
       
            # Unpack observations into data structure compatible with agent Policy
            agents_obs = unpack_env_obs(env_obs)
            load_info(agents, narrate=False)   # Load agent info for AI agents

            # For learner agents only, generate reward statistics and reward stack for policy gradient
            for i in range(num_learners):
                agents[i].rewards.append(reward[i])  # Stack rewards (for policy gradient)
                episode_reward[i] += reward[i]   # accumulate episode reward 
            
            """
            For now, we do not stack observation, may come in handy later on
        
            # Evict oldest diff add new diff to state
            next_state = np.stack([next_state]*num_frames)
            next_state[1:, :, :] = state[:-1, :, :]
            state = next_state
            """

            if any(done):
                print("Done after {} frames".format(frame))
                break
            
        if frame > max_frames_ep:
            max_frames_ep = frame    # Keep track of highest frames/episode

        # Update reward statistics for learners
        for i in range(num_learners):
            if running_reward[i] is None:
                running_reward[i] = episode_reward[i]
            running_reward[i] = running_reward[i] * 0.99 + episode_reward[i] * 0.01
            running_rewards[i].append(running_reward[i])

        # Track Episode #, temp and highest frames/episode
        if (ep+prior_eps+1) % log_interval == 0: 
            verbose_str = '\nEpisode {} complete'.format(ep+prior_eps+1)
            # verbose_str += '\tTemp = {:.4}'.format(model.temperature)
            # verbose_str += '\tMax frames = {}'.format(max_frames_ep+1)
            print(verbose_str)
    
            # Display rewards and running rewards for learning agents
            for i in range(num_learners):
                verbose_str = 'Learner:{}'.format(i)
                verbose_str += '\tReward total:{}'.format(episode_reward[i])
                verbose_str += '\tRunning mean: {:.4}'.format(running_reward[i])
                print(verbose_str)
    
        # Update model
        total_norms = finish_episode(agents[0:num_learners], optimizers[0:num_learners], gamma, cuda)

        if (ep+prior_eps+1) % log_interval == 0:
            print('Max Norms = ',["%0.2f" % i for i in total_norms])
        
        if (ep+prior_eps+1) % save_interval == 0: 
            for i in range(num_learners):

                model_file = 'MA_models/{}-01/p{}_r{}/MA{}_{}__ep{}.p'.format(culture['name'], culture['penalty'],\
                                 culture['reward'], i, game, ep+prior_eps+1)
                data_file = 'results/{}-01/p{}_r{}/MA{}_{}.p'.format(culture['name'], culture['penalty'],\
                                                      culture['reward'], i, game)
                
                os.makedirs(os.path.dirname(model_file), exist_ok=True)
                os.makedirs(os.path.dirname(data_file), exist_ok=True)
                
                with open(model_file, 'wb') as f:
                    # Model Save and Load Update: Include both model and optim parameters 
                    pickle.dump((agents[i].cpu(), optimizers[i]), f)

                if cuda:
                    agents[i] = agents[i].cuda()

                with open(data_file, 'wb') as f:
                    pickle.dump(running_rewards[i], f)    
            
    env.close()  # Close the environment
# Out:
# Learner agent 0
# Learner agent 1
# Learner agent 2
# Learner agent 3
# Learner agent 4
# Learner agent 5
# Learner agent 6
# Learner agent 7
# Load random agent 8
# ....................................................................................................
# Episode 100 complete
# Learner:0	Reward total:0	Running mean: 0.4331
# Learner:1	Reward total:0	Running mean: 0.2733
# Learner:2	Reward total:0	Running mean: 0.2881
# Learner:3	Reward total:3	Running mean: 0.6219
# Learner:4	Reward total:0	Running mean: 0.4593
# Learner:5	Reward total:0	Running mean: 0.744
# Learner:6	Reward total:0	Running mean: 0.8516
# Learner:7	Reward total:17	Running mean: 7.254
# Max Norms =  ['220.89', '260.40', '0.00', '274.02', '222.68', '236.76', '187.13', '256.05']
# ....................................................................................................
# Episode 200 complete
# Learner:0	Reward total:0	Running mean: 2.735
# Learner:1	Reward total:0	Running mean: 0.5942
# Learner:2	Reward total:5	Running mean: 5.077
# Learner:3	Reward total:10	Running mean: 6.209
# Learner:4	Reward total:13	Running mean: 4.057
# Learner:5	Reward total:12	Running mean: 2.986
# Learner:6	Reward total:9	Running mean: 5.378
# Learner:7	Reward total:215	Running mean: 72.68
# Max Norms =  ['0.00', '0.00', '301.77', '315.63', '211.31', '258.90', '198.39', '230.02']
# ....................................................................................................
# Episode 300 complete
# Learner:0	Reward total:19	Running mean: 9.591
# Learner:1	Reward total:0	Running mean: 0.6422
# Learner:2	Reward total:80	Running mean: 38.52
# Learner:3	Reward total:25	Running mean: 15.67
# Learner:4	Reward total:32	Running mean: 15.75
# Learner:5	Reward total:22	Running mean: 8.772
# Learner:6	Reward total:65	Running mean: 32.04
# Learner:7	Reward total:160	Running mean: 124.6
# Max Norms =  ['251.68', '0.00', '185.14', '245.95', '255.58', '200.33', '238.80', '256.05']
# ....................................................................................................
# Episode 400 complete
# Learner:0	Reward total:31	Running mean: 25.29
# Learner:1	Reward total:5	Running mean: 1.022
# Learner:2	Reward total:87	Running mean: 61.71
# Learner:3	Reward total:35	Running mean: 24.76
# Learner:4	Reward total:59	Running mean: 33.18
# Learner:5	Reward total:22	Running mean: 14.68
# Learner:6	Reward total:84	Running mean: 62.24
# Learner:7	Reward total:144	Running mean: 144.1
# Max Norms =  ['267.07', '180.30', '289.24', '253.89', '238.25', '162.37', '241.75', '406.69']
# ....................................................................................................
# Episode 500 complete
# Learner:0	Reward total:27	Running mean: 30.72
# Learner:1	Reward total:2	Running mean: 3.296
# Learner:2	Reward total:62	Running mean: 58.07
# Learner:3	Reward total:14	Running mean: 30.31
# Learner:4	Reward total:79	Running mean: 52.9
# Learner:5	Reward total:19	Running mean: 16.72
# Learner:6	Reward total:77	Running mean: 77.77
# Learner:7	Reward total:120	Running mean: 130.8
# Max Norms =  ['147.32', '167.01', '238.52', '173.24', '233.33', '196.48', '275.07', '329.13']
# ....................................................................................................
# Episode 600 complete
# Learner:0	Reward total:16	Running mean: 26.86
# Learner:1	Reward total:11	Running mean: 6.944
# Learner:2	Reward total:38	Running mean: 43.32
# Learner:3	Reward total:39	Running mean: 39.89
# Learner:4	Reward total:78	Running mean: 61.93
# Learner:5	Reward total:10	Running mean: 15.7
# Learner:6	Reward total:74	Running mean: 76.17
# Learner:7	Reward total:115	Running mean: 119.3
# Max Norms =  ['123.31', '136.19', '309.79', '197.16', '247.33', '116.15', '221.97', '342.01']
# ....................................................................................................
# Episode 700 complete
# Learner:0	Reward total:19	Running mean: 23.14
# Learner:1	Reward total:18	Running mean: 10.16
# Learner:2	Reward total:43	Running mean: 38.08
# Learner:3	Reward total:85	Running mean: 64.24
# Learner:4	Reward total:53	Running mean: 57.64
# Learner:5	Reward total:27	Running mean: 13.61
# Learner:6	Reward total:50	Running mean: 63.45
# Learner:7	Reward total:98	Running mean: 109.1
# Max Norms =  ['123.53', '216.41', '233.90', '219.57', '157.14', '147.56', '181.70', '204.08']
# ....................................................................................................
# Episode 800 complete
# Learner:0	Reward total:13	Running mean: 20.89
# Learner:1	Reward total:18	Running mean: 14.48
# Learner:2	Reward total:51	Running mean: 35.02
# Learner:3	Reward total:80	Running mean: 78.82
# Learner:4	Reward total:21	Running mean: 55.44
# Learner:5	Reward total:13	Running mean: 14.4
# Learner:6	Reward total:54	Running mean: 60.73
# Learner:7	Reward total:137	Running mean: 102.4
# Max Norms =  ['119.01', '136.31', '169.97', '167.21', '166.07', '83.51', '243.92', '197.98']
# ....................................................................................................
# Episode 900 complete
# Learner:0	Reward total:11	Running mean: 18.85
# Learner:1	Reward total:18	Running mean: 18.52
# Learner:2	Reward total:16	Running mean: 33.93
# Learner:3	Reward total:101	Running mean: 79.02
# Learner:4	Reward total:33	Running mean: 54.01
# Learner:5	Reward total:24	Running mean: 16.59
# Learner:6	Reward total:105	Running mean: 64.96
# Learner:7	Reward total:60	Running mean: 97.92
# Max Norms =  ['111.85', '149.74', '223.50', '184.40', '173.89', '128.61', '308.48', '223.17']
# ....................................................................................................
# Episode 1000 complete
# Learner:0	Reward total:16	Running mean: 17.54
# Learner:1	Reward total:25	Running mean: 19.67
# Learner:2	Reward total:12	Running mean: 31.36
# Learner:3	Reward total:64	Running mean: 88.64
# Learner:4	Reward total:52	Running mean: 56.32
# Learner:5	Reward total:15	Running mean: 15.65
# Learner:6	Reward total:126	Running mean: 58.99
# Learner:7	Reward total:40	Running mean: 94.41
# Max Norms =  ['120.41', '196.41', '165.32', '176.60', '200.35', '64.20', '211.85', '242.52']
# ....................................................................................................
# Episode 1100 complete
# Learner:0	Reward total:12	Running mean: 16.25
# Learner:1	Reward total:22	Running mean: 20.24
# Learner:2	Reward total:14	Running mean: 28.26
# Learner:3	Reward total:60	Running mean: 70.29
# Learner:4	Reward total:101	Running mean: 55.21
# Learner:5	Reward total:12	Running mean: 16.83
# Learner:6	Reward total:99	Running mean: 72.06
# Learner:7	Reward total:27	Running mean: 91.93
# Max Norms =  ['112.59', '154.86', '126.77', '120.25', '148.83', '135.91', '193.51', '365.78']
# ....................................................................................................
# Episode 1200 complete
# Learner:0	Reward total:17	Running mean: 17.68
# Learner:1	Reward total:30	Running mean: 22.3
# Learner:2	Reward total:30	Running mean: 26.95
# Learner:3	Reward total:56	Running mean: 79.36
# Learner:4	Reward total:59	Running mean: 54.39
# Learner:5	Reward total:7	Running mean: 16.33
# Learner:6	Reward total:121	Running mean: 76.68
# Learner:7	Reward total:94	Running mean: 85.19
# Max Norms =  ['163.34', '164.72', '123.26', '157.81', '178.47', '78.86', '251.93', '681.62']
# ....................................................................................................
# Episode 1300 complete
# Learner:0	Reward total:28	Running mean: 19.19
# Learner:1	Reward total:25	Running mean: 24.69
# Learner:2	Reward total:23	Running mean: 30.64
# Learner:3	Reward total:107	Running mean: 93.75
# Learner:4	Reward total:62	Running mean: 54.66
# Learner:5	Reward total:7	Running mean: 15.98
# Learner:6	Reward total:62	Running mean: 74.93
# Learner:7	Reward total:82	Running mean: 76.82
# Max Norms =  ['205.91', '210.20', '48.98', '174.62', '347.73', '59.12', '223.35', '390.56']
# ....................................................................................................
# Episode 1400 complete
# Learner:0	Reward total:11	Running mean: 19.64
# Learner:1	Reward total:5	Running mean: 25.6
# Learner:2	Reward total:46	Running mean: 31.99
# Learner:3	Reward total:76	Running mean: 83.72
# Learner:4	Reward total:37	Running mean: 56.51
# Learner:5	Reward total:14	Running mean: 17.35
# Learner:6	Reward total:79	Running mean: 80.04
# Learner:7	Reward total:80	Running mean: 75.38
# Max Norms =  ['143.76', '153.40', '95.07', '167.55', '112.98', '118.31', '325.60', '258.40']
# ....................................................................................................
# Episode 1500 complete
# Learner:0	Reward total:43	Running mean: 20.78
# Learner:1	Reward total:14	Running mean: 22.13
# Learner:2	Reward total:35	Running mean: 32.25
# Learner:3	Reward total:84	Running mean: 83.64
# Learner:4	Reward total:60	Running mean: 54.42
# Learner:5	Reward total:16	Running mean: 15.7
# Learner:6	Reward total:92	Running mean: 79.97
# Learner:7	Reward total:93	Running mean: 76.57
# Max Norms =  ['174.82', '110.17', '194.00', '199.48', '236.25', '50.63', '281.91', '354.24']
# ....................................................................................................
# Episode 1600 complete
# Learner:0	Reward total:15	Running mean: 19.64
# Learner:1	Reward total:7	Running mean: 21.18
# Learner:2	Reward total:19	Running mean: 28.49
# Learner:3	Reward total:110	Running mean: 82.19
# Learner:4	Reward total:34	Running mean: 48.05
# Learner:5	Reward total:10	Running mean: 14.89
# Learner:6	Reward total:54	Running mean: 95.11
# Learner:7	Reward total:151	Running mean: 86.76
# Max Norms =  ['148.02', '125.42', '82.31', '222.57', '240.11', '59.43', '175.79', '639.57']
# ....................................................................................................
# Episode 1700 complete
# Learner:0	Reward total:19	Running mean: 18.49
# Learner:1	Reward total:14	Running mean: 21.7
# Learner:2	Reward total:36	Running mean: 26.78
# Learner:3	Reward total:80	Running mean: 78.54
# Learner:4	Reward total:74	Running mean: 57.19
# Learner:5	Reward total:8	Running mean: 14.49
# Learner:6	Reward total:136	Running mean: 99.62
# Learner:7	Reward total:38	Running mean: 82.68
# Max Norms =  ['154.68', '168.70', '128.58', '306.04', '180.16', '76.54', '191.27', '286.92']
# ....................................................................................................
# Episode 1800 complete
# Learner:0	Reward total:19	Running mean: 21.38
# Learner:1	Reward total:9	Running mean: 22.19
# Learner:2	Reward total:34	Running mean: 28.65
# Learner:3	Reward total:60	Running mean: 86.39
# Learner:4	Reward total:48	Running mean: 48.14
# Learner:5	Reward total:7	Running mean: 14.16
# Learner:6	Reward total:151	Running mean: 95.26
# Learner:7	Reward total:113	Running mean: 99.25
# Max Norms =  ['215.37', '130.00', '115.07', '200.42', '184.49', '80.37', '242.47', '270.46']
# ....................................................................................................
# Episode 1900 complete
# Learner:0	Reward total:11	Running mean: 24.43
# Learner:1	Reward total:43	Running mean: 26.36
# Learner:2	Reward total:28	Running mean: 26.67
# Learner:3	Reward total:120	Running mean: 79.07
# Learner:4	Reward total:37	Running mean: 42.34
# Learner:5	Reward total:11	Running mean: 16.15
# Learner:6	Reward total:69	Running mean: 109.2
# Learner:7	Reward total:107	Running mean: 95.65
# Max Norms =  ['160.55', '145.22', '84.11', '189.68', '154.74', '64.26', '169.67', '243.63']
# ....................................................................................................
# Episode 2000 complete
# Learner:0	Reward total:14	Running mean: 25.78
# Learner:1	Reward total:20	Running mean: 27.97
# Learner:2	Reward total:12	Running mean: 27.83
# Learner:3	Reward total:27	Running mean: 66.44
# Learner:4	Reward total:60	Running mean: 53.86
# Learner:5	Reward total:27	Running mean: 18.02
# Learner:6	Reward total:177	Running mean: 108.3
# Learner:7	Reward total:77	Running mean: 92.92
# Max Norms =  ['348.41', '90.62', '61.83', '120.54', '201.52', '57.16', '226.61', '446.90']
# ....................................................................................................
# Episode 2100 complete
# Learner:0	Reward total:14	Running mean: 24.96
# Learner:1	Reward total:24	Running mean: 27.87
# Learner:2	Reward total:18	Running mean: 27.42
# Learner:3	Reward total:51	Running mean: 64.36
# Learner:4	Reward total:87	Running mean: 53.32
# Learner:5	Reward total:19	Running mean: 16.7
# Learner:6	Reward total:69	Running mean: 107.3
# Learner:7	Reward total:84	Running mean: 91.12
# Max Norms =  ['200.19', '246.00', '61.61', '215.84', '139.68', '146.01', '305.26', '685.98']
# ....................................................................................................
# Episode 2200 complete
# Learner:0	Reward total:21	Running mean: 25.33
# Learner:1	Reward total:21	Running mean: 27.06
# Learner:2	Reward total:24	Running mean: 29.78
# Learner:3	Reward total:74	Running mean: 68.34
# Learner:4	Reward total:49	Running mean: 55.81
# Learner:5	Reward total:17	Running mean: 16.0
# Learner:6	Reward total:117	Running mean: 94.14
# Learner:7	Reward total:58	Running mean: 88.61
# Max Norms =  ['167.63', '207.15', '98.63', '203.15', '96.56', '80.04', '214.82', '289.70']
# ....................................................................................................
# Episode 2300 complete
# Learner:0	Reward total:40	Running mean: 26.77
# Learner:1	Reward total:8	Running mean: 24.77
# Learner:2	Reward total:27	Running mean: 33.03
# Learner:3	Reward total:50	Running mean: 77.23
# Learner:4	Reward total:51	Running mean: 52.92
# Learner:5	Reward total:20	Running mean: 15.79
# Learner:6	Reward total:102	Running mean: 80.38
# Learner:7	Reward total:129	Running mean: 87.38
# Max Norms =  ['240.68', '62.49', '185.27', '180.96', '178.16', '91.95', '235.98', '389.73']
# ....................................................................................................
# Episode 2400 complete
# Learner:0	Reward total:30	Running mean: 27.99
# Learner:1	Reward total:29	Running mean: 26.01
# Learner:2	Reward total:20	Running mean: 25.76
# Learner:3	Reward total:72	Running mean: 78.24
# Learner:4	Reward total:54	Running mean: 48.54
# Learner:5	Reward total:10	Running mean: 13.29
# Learner:6	Reward total:73	Running mean: 87.03
# Learner:7	Reward total:100	Running mean: 93.32
# Max Norms =  ['120.07', '43.26', '87.78', '138.87', '245.98', '48.18', '204.22', '255.03']
# ....................................................................................................
# Episode 2500 complete
# Learner:0	Reward total:23	Running mean: 25.72
# Learner:1	Reward total:51	Running mean: 29.71
# Learner:2	Reward total:35	Running mean: 25.13
# Learner:3	Reward total:82	Running mean: 77.17
# Learner:4	Reward total:42	Running mean: 50.98
# Learner:5	Reward total:2	Running mean: 14.69
# Learner:6	Reward total:112	Running mean: 99.24
# Learner:7	Reward total:37	Running mean: 100.3
# Max Norms =  ['245.01', '161.69', '96.09', '130.66', '104.55', '33.35', '248.36', '385.54']
# ....................................................................................................
# Episode 2600 complete
# Learner:0	Reward total:9	Running mean: 22.63
# Learner:1	Reward total:18	Running mean: 29.11
# Learner:2	Reward total:20	Running mean: 21.25
# Learner:3	Reward total:64	Running mean: 69.87
# Learner:4	Reward total:45	Running mean: 54.83
# Learner:5	Reward total:15	Running mean: 15.09
# Learner:6	Reward total:132	Running mean: 102.9
# Learner:7	Reward total:95	Running mean: 91.93
# Max Norms =  ['172.98', '110.09', '71.55', '244.75', '120.72', '58.92', '141.47', '292.15']
# ....................................................................................................
# Episode 2700 complete
# Learner:0	Reward total:25	Running mean: 22.86
# Learner:1	Reward total:24	Running mean: 27.18
# Learner:2	Reward total:17	Running mean: 20.34
# Learner:3	Reward total:92	Running mean: 66.77
# Learner:4	Reward total:20	Running mean: 48.71
# Learner:5	Reward total:15	Running mean: 16.64
# Learner:6	Reward total:68	Running mean: 103.9
# Learner:7	Reward total:122	Running mean: 92.41
# Max Norms =  ['211.21', '132.00', '96.10', '222.12', '259.45', '67.75', '145.33', '266.82']
# ....................................................................................................
# Episode 2800 complete
# Learner:0	Reward total:29	Running mean: 25.57
# Learner:1	Reward total:37	Running mean: 27.12
# Learner:2	Reward total:31	Running mean: 21.08
# Learner:3	Reward total:37	Running mean: 63.48
# Learner:4	Reward total:41	Running mean: 45.73
# Learner:5	Reward total:41	Running mean: 19.68
# Learner:6	Reward total:102	Running mean: 111.9
# Learner:7	Reward total:126	Running mean: 92.81
# Max Norms =  ['92.54', '87.28', '88.46', '197.68', '181.13', '53.77', '251.16', '409.08']
# ....................................................................................................
# Episode 2900 complete
# Learner:0	Reward total:31	Running mean: 28.05
# Learner:1	Reward total:23	Running mean: 29.42
# Learner:2	Reward total:16	Running mean: 20.8
# Learner:3	Reward total:58	Running mean: 56.82
# Learner:4	Reward total:75	Running mean: 53.56
# Learner:5	Reward total:19	Running mean: 17.48
# Learner:6	Reward total:90	Running mean: 117.7
# Learner:7	Reward total:121	Running mean: 93.26
# Max Norms =  ['174.05', '51.99', '205.87', '104.78', '158.07', '40.36', '205.02', '438.29']
# ....................................................................................................
# Episode 3000 complete
# Learner:0	Reward total:50	Running mean: 27.2
# Learner:1	Reward total:22	Running mean: 27.78
# Learner:2	Reward total:16	Running mean: 20.71
# Learner:3	Reward total:69	Running mean: 60.5
# Learner:4	Reward total:44	Running mean: 54.1
# Learner:5	Reward total:5	Running mean: 16.29
# Learner:6	Reward total:162	Running mean: 120.5
# Learner:7	Reward total:75	Running mean: 80.51
# Max Norms =  ['127.70', '39.12', '142.65', '124.33', '158.15', '135.27', '315.78', '321.06']
# ....................................................................................................
# Episode 3100 complete
# Learner:0	Reward total:41	Running mean: 28.5
# Learner:1	Reward total:28	Running mean: 24.48
# Learner:2	Reward total:36	Running mean: 20.03
# Learner:3	Reward total:94	Running mean: 65.95
# Learner:4	Reward total:72	Running mean: 50.09
# Learner:5	Reward total:14	Running mean: 16.14
# Learner:6	Reward total:15	Running mean: 124.5
# Learner:7	Reward total:139	Running mean: 78.01
# Max Norms =  ['162.27', '170.44', '144.51', '244.34', '188.86', '54.45', '264.53', '299.65']
# ....................................................................................................
# Episode 3200 complete
# Learner:0	Reward total:44	Running mean: 30.07
# Learner:1	Reward total:21	Running mean: 23.66
# Learner:2	Reward total:22	Running mean: 23.97
# Learner:3	Reward total:61	Running mean: 79.47
# Learner:4	Reward total:80	Running mean: 50.96
# Learner:5	Reward total:12	Running mean: 15.49
# Learner:6	Reward total:53	Running mean: 103.5
# Learner:7	Reward total:145	Running mean: 97.43
# Max Norms =  ['159.28', '76.66', '64.82', '218.24', '139.82', '27.49', '530.64', '405.31']
# ....................................................................................................
# Episode 3300 complete
# Learner:0	Reward total:11	Running mean: 27.6
# Learner:1	Reward total:24	Running mean: 24.74
# Learner:2	Reward total:2	Running mean: 19.09
# Learner:3	Reward total:6	Running mean: 68.68
# Learner:4	Reward total:106	Running mean: 49.87
# Learner:5	Reward total:15	Running mean: 15.66
# Learner:6	Reward total:162	Running mean: 134.4
# Learner:7	Reward total:48	Running mean: 83.61
# Max Norms =  ['226.10', '62.73', '142.88', '338.38', '255.19', '10.78', '388.27', '307.54']
# ....................................................................................................
# Episode 3400 complete
# Learner:0	Reward total:25	Running mean: 26.46
# Learner:1	Reward total:32	Running mean: 25.13
# Learner:2	Reward total:19	Running mean: 17.1
# Learner:3	Reward total:39	Running mean: 54.24
# Learner:4	Reward total:37	Running mean: 48.71
# Learner:5	Reward total:20	Running mean: 14.53
# Learner:6	Reward total:196	Running mean: 163.8
# Learner:7	Reward total:53	Running mean: 74.91
# Max Norms =  ['125.68', '160.50', '156.85', '214.37', '94.35', '152.35', '384.86', '330.59']
# ....................................................................................................
# Episode 3500 complete
# Learner:0	Reward total:26	Running mean: 27.04
# Learner:1	Reward total:22	Running mean: 23.82
# Learner:2	Reward total:14	Running mean: 20.1
# Learner:3	Reward total:82	Running mean: 71.08
# Learner:4	Reward total:49	Running mean: 47.51
# Learner:5	Reward total:13	Running mean: 14.9
# Learner:6	Reward total:172	Running mean: 154.4
# Learner:7	Reward total:108	Running mean: 85.73
# Max Norms =  ['234.98', '96.69', '115.61', '200.36', '141.68', '77.95', '366.30', '281.81']
# ....................................................................................................
# Episode 3600 complete
# Learner:0	Reward total:5	Running mean: 23.37
# Learner:1	Reward total:21	Running mean: 23.3
# Learner:2	Reward total:5	Running mean: 18.5
# Learner:3	Reward total:28	Running mean: 60.3
# Learner:4	Reward total:46	Running mean: 41.74
# Learner:5	Reward total:20	Running mean: 14.52
# Learner:6	Reward total:215	Running mean: 184.5
# Learner:7	Reward total:46	Running mean: 79.63
# Max Norms =  ['120.24', '75.80', '93.33', '247.29', '209.35', '65.22', '353.95', '225.29']
# ....................................................................................................
# Episode 3700 complete
# Learner:0	Reward total:12	Running mean: 19.97
# Learner:1	Reward total:31	Running mean: 26.45
# Learner:2	Reward total:11	Running mean: 18.85
# Learner:3	Reward total:46	Running mean: 58.31
# Learner:4	Reward total:40	Running mean: 43.96
# Learner:5	Reward total:24	Running mean: 16.36
# Learner:6	Reward total:121	Running mean: 167.9
# Learner:7	Reward total:121	Running mean: 79.12
# Max Norms =  ['194.64', '130.00', '158.05', '191.68', '203.70', '125.72', '219.33', '399.34']
# ....................................................................................................
# Episode 3800 complete
# Learner:0	Reward total:21	Running mean: 18.54
# Learner:1	Reward total:21	Running mean: 27.17
# Learner:2	Reward total:4	Running mean: 18.08
# Learner:3	Reward total:45	Running mean: 52.66
# Learner:4	Reward total:39	Running mean: 44.11
# Learner:5	Reward total:26	Running mean: 17.99
# Learner:6	Reward total:232	Running mean: 166.1
# Learner:7	Reward total:57	Running mean: 81.79
# Max Norms =  ['169.85', '67.27', '35.10', '191.26', '195.48', '19.78', '392.56', '309.00']
# ....................................................................................................
# Episode 3900 complete
# Learner:0	Reward total:8	Running mean: 16.14
# Learner:1	Reward total:63	Running mean: 31.0
# Learner:2	Reward total:22	Running mean: 14.35
# Learner:3	Reward total:45	Running mean: 38.91
# Learner:4	Reward total:51	Running mean: 47.9
# Learner:5	Reward total:15	Running mean: 17.26
# Learner:6	Reward total:182	Running mean: 184.5
# Learner:7	Reward total:44	Running mean: 73.46
# Max Norms =  ['75.87', '156.18', '36.70', '167.18', '104.11', '60.51', '438.94', '274.64']
# ....................................................................................................
# Episode 4000 complete
# Learner:0	Reward total:5	Running mean: 14.78
# Learner:1	Reward total:36	Running mean: 30.26
# Learner:2	Reward total:10	Running mean: 15.69
# Learner:3	Reward total:77	Running mean: 47.11
# Learner:4	Reward total:50	Running mean: 60.58
# Learner:5	Reward total:2	Running mean: 15.9
# Learner:6	Reward total:177	Running mean: 157.9
# Learner:7	Reward total:45	Running mean: 61.0
# Max Norms =  ['134.34', '95.46', '80.93', '238.12', '193.28', '23.88', '737.40', '396.50']
# ....................................................................................................
# Episode 4100 complete
# Learner:0	Reward total:14	Running mean: 16.14
# Learner:1	Reward total:48	Running mean: 29.69
# Learner:2	Reward total:29	Running mean: 17.68
# Learner:3	Reward total:32	Running mean: 45.58
# Learner:4	Reward total:50	Running mean: 58.53
# Learner:5	Reward total:32	Running mean: 17.82
# Learner:6	Reward total:150	Running mean: 151.8
# Learner:7	Reward total:54	Running mean: 69.44
# Max Norms =  ['118.69', '111.35', '106.37', '192.60', '213.24', '81.97', '427.74', '430.31']
# ....................................................................................................
# Episode 4200 complete
# Learner:0	Reward total:18	Running mean: 19.0
# Learner:1	Reward total:40	Running mean: 30.08
# Learner:2	Reward total:27	Running mean: 18.42
# Learner:3	Reward total:25	Running mean: 47.45
# Learner:4	Reward total:87	Running mean: 62.82
# Learner:5	Reward total:21	Running mean: 19.48
# Learner:6	Reward total:190	Running mean: 144.9
# Learner:7	Reward total:13	Running mean: 75.65
# Max Norms =  ['170.81', '86.23', '33.84', '211.89', '243.14', '0.91', '385.42', '259.65']
# ....................................................................................................
# Episode 4300 complete
# Learner:0	Reward total:30	Running mean: 21.77
# Learner:1	Reward total:35	Running mean: 29.65
# Learner:2	Reward total:10	Running mean: 17.39
# Learner:3	Reward total:30	Running mean: 51.08
# Learner:4	Reward total:62	Running mean: 63.68
# Learner:5	Reward total:16	Running mean: 18.64
# Learner:6	Reward total:168	Running mean: 138.0
# Learner:7	Reward total:84	Running mean: 69.38
# Max Norms =  ['134.69', '90.32', '105.65', '247.30', '198.94', '0.81', '308.83', '312.91']
# ....................................................................................................
# Episode 4400 complete
# Learner:0	Reward total:20	Running mean: 23.17
# Learner:1	Reward total:43	Running mean: 32.3
# Learner:2	Reward total:13	Running mean: 17.38
# Learner:3	Reward total:41	Running mean: 43.75
# Learner:4	Reward total:25	Running mean: 57.59
# Learner:5	Reward total:16	Running mean: 19.31
# Learner:6	Reward total:252	Running mean: 153.7
# Learner:7	Reward total:44	Running mean: 69.52
# Max Norms =  ['180.50', '94.54', '117.78', '199.10', '209.87', '1.67', '411.05', '375.71']
# ....................................................................................................
# Episode 4500 complete
# Learner:0	Reward total:25	Running mean: 21.69
# Learner:1	Reward total:39	Running mean: 35.09
# Learner:2	Reward total:6	Running mean: 15.74
# Learner:3	Reward total:12	Running mean: 38.52
# Learner:4	Reward total:18	Running mean: 53.71
# Learner:5	Reward total:16	Running mean: 19.15
# Learner:6	Reward total:247	Running mean: 173.0
# Learner:7	Reward total:99	Running mean: 68.88
# Max Norms =  ['123.40', '112.15', '163.66', '268.69', '179.85', '54.22', '628.71', '290.34']
# ....................................................................................................
# Episode 4600 complete
# Learner:0	Reward total:7	Running mean: 20.4
# Learner:1	Reward total:23	Running mean: 31.21
# Learner:2	Reward total:11	Running mean: 16.96
# Learner:3	Reward total:65	Running mean: 42.05
# Learner:4	Reward total:32	Running mean: 58.09
# Learner:5	Reward total:7	Running mean: 13.96
# Learner:6	Reward total:147	Running mean: 157.5
# Learner:7	Reward total:82	Running mean: 67.09
# Max Norms =  ['81.69', '80.37', '52.91', '184.01', '179.32', '124.66', '420.25', '268.23']
# ....................................................................................................
# Episode 4700 complete
# Learner:0	Reward total:27	Running mean: 20.87
# Learner:1	Reward total:14	Running mean: 25.84
# Learner:2	Reward total:35	Running mean: 15.37
# Learner:3	Reward total:38	Running mean: 38.05
# Learner:4	Reward total:74	Running mean: 66.44
# Learner:5	Reward total:19	Running mean: 12.97
# Learner:6	Reward total:70	Running mean: 140.8
# Learner:7	Reward total:143	Running mean: 66.34
# Max Norms =  ['109.54', '268.10', '188.54', '234.34', '291.34', '139.10', '282.23', '281.93']
# ....................................................................................................
# Episode 4800 complete
# Learner:0	Reward total:7	Running mean: 21.19
# Learner:1	Reward total:20	Running mean: 23.85
# Learner:2	Reward total:22	Running mean: 14.48
# Learner:3	Reward total:70	Running mean: 47.64
# Learner:4	Reward total:20	Running mean: 60.49
# Learner:5	Reward total:20	Running mean: 13.31
# Learner:6	Reward total:111	Running mean: 139.0
# Learner:7	Reward total:94	Running mean: 71.54
# Max Norms =  ['101.86', '155.22', '131.21', '209.68', '247.01', '17.67', '360.06', '257.35']
# ....................................................................................................
# Episode 4900 complete
# Learner:0	Reward total:20	Running mean: 20.94
# Learner:1	Reward total:23	Running mean: 24.73
# Learner:2	Reward total:10	Running mean: 14.96
# Learner:3	Reward total:46	Running mean: 54.81
# Learner:4	Reward total:61	Running mean: 64.53
# Learner:5	Reward total:23	Running mean: 17.21
# Learner:6	Reward total:130	Running mean: 126.1
# Learner:7	Reward total:148	Running mean: 79.89
# Max Norms =  ['173.82', '61.29', '94.04', '301.23', '286.10', '17.17', '328.44', '530.19']
# ....................................................................................................
# Episode 5000 complete
# Learner:0	Reward total:17	Running mean: 19.76
# Learner:1	Reward total:14	Running mean: 26.29
# Learner:2	Reward total:9	Running mean: 12.48
# Learner:3	Reward total:18	Running mean: 48.69
# Learner:4	Reward total:119	Running mean: 65.1
# Learner:5	Reward total:15	Running mean: 18.27
# Learner:6	Reward total:73	Running mean: 121.5
# Learner:7	Reward total:105	Running mean: 108.2
# Max Norms =  ['220.47', '102.00', '95.02', '202.44', '147.76', '0.62', '317.76', '285.74']
# Learner agent 0
# Learner agent 1
# Learner agent 2
# Learner agent 3
# Learner agent 4
# Learner agent 5
# Learner agent 6
# Learner agent 7
# Load random agent 8
# ....................................................................................................
# Episode 100 complete
# Learner:0	Reward total:0	Running mean: 0.7018
# Learner:1	Reward total:6	Running mean: 0.3308
# Learner:2	Reward total:4	Running mean: 1.239
# Learner:3	Reward total:0	Running mean: 0.344
# Learner:4	Reward total:4	Running mean: 0.974
# Learner:5	Reward total:0	Running mean: 0.5472
# Learner:6	Reward total:0	Running mean: 0.9828
# Learner:7	Reward total:5	Running mean: 5.445
# Max Norms =  ['299.01', '203.95', '191.15', '191.62', '177.23', '165.22', '228.59', '255.12']
# ....................................................................................................
# Episode 200 complete
# Learner:0	Reward total:37	Running mean: 13.58
# Learner:1	Reward total:0	Running mean: 0.4837
# Learner:2	Reward total:42	Running mean: 13.92
# Learner:3	Reward total:0	Running mean: 0.7326
# Learner:4	Reward total:27	Running mean: 9.749
# Learner:5	Reward total:9	Running mean: 5.724
# Learner:6	Reward total:61	Running mean: 11.17
# Learner:7	Reward total:92	Running mean: 32.68
# Max Norms =  ['209.35', '0.00', '205.02', '221.03', '215.81', '209.22', '206.50', '215.34']
# ....................................................................................................
# Episode 300 complete
# Learner:0	Reward total:41	Running mean: 40.83
# Learner:1	Reward total:0	Running mean: 0.9616
# Learner:2	Reward total:61	Running mean: 49.5
# Learner:3	Reward total:0	Running mean: 1.255
# Learner:4	Reward total:49	Running mean: 28.83
# Learner:5	Reward total:80	Running mean: 24.75
# Learner:6	Reward total:62	Running mean: 48.49
# Learner:7	Reward total:117	Running mean: 74.86
# Max Norms =  ['219.54', '182.64', '202.27', '163.17', '243.53', '244.66', '615.62', '227.85']
# ....................................................................................................
# Episode 400 complete
# Learner:0	Reward total:40	Running mean: 52.68
# Learner:1	Reward total:12	Running mean: 3.015
# Learner:2	Reward total:37	Running mean: 62.65
# Learner:3	Reward total:0	Running mean: 1.571
# Learner:4	Reward total:117	Running mean: 60.66
# Learner:5	Reward total:68	Running mean: 54.93
# Learner:6	Reward total:82	Running mean: 69.19
# Learner:7	Reward total:96	Running mean: 87.01
# Max Norms =  ['250.33', '171.76', '232.19', '189.41', '307.04', '275.32', '189.24', '233.95']
# ....................................................................................................
# Episode 500 complete
# Learner:0	Reward total:21	Running mean: 42.58
# Learner:1	Reward total:11	Running mean: 8.445
# Learner:2	Reward total:35	Running mean: 54.7
# Learner:3	Reward total:0	Running mean: 1.335
# Learner:4	Reward total:116	Running mean: 103.0
# Learner:5	Reward total:20	Running mean: 47.23
# Learner:6	Reward total:42	Running mean: 57.47
# Learner:7	Reward total:134	Running mean: 90.97
# Max Norms =  ['206.59', '144.64', '175.48', '156.66', '233.45', '155.98', '149.57', '271.33']
# ....................................................................................................
# Episode 600 complete
# Learner:0	Reward total:22	Running mean: 36.98
# Learner:1	Reward total:14	Running mean: 14.34
# Learner:2	Reward total:106	Running mean: 62.06
# Learner:3	Reward total:1	Running mean: 2.351
# Learner:4	Reward total:157	Running mean: 109.9
# Learner:5	Reward total:44	Running mean: 38.1
# Learner:6	Reward total:48	Running mean: 42.85
# Learner:7	Reward total:62	Running mean: 100.3
# Max Norms =  ['216.16', '252.01', '274.63', '165.70', '262.87', '284.92', '157.62', '166.14']
# ....................................................................................................
# Episode 700 complete
# Learner:0	Reward total:28	Running mean: 31.81
# Learner:1	Reward total:19	Running mean: 20.13
# Learner:2	Reward total:91	Running mean: 88.53
# Learner:3	Reward total:18	Running mean: 5.466
# Learner:4	Reward total:62	Running mean: 95.02
# Learner:5	Reward total:24	Running mean: 33.49
# Learner:6	Reward total:20	Running mean: 37.5
# Learner:7	Reward total:103	Running mean: 92.16
# Max Norms =  ['224.02', '78.42', '295.66', '152.59', '283.38', '355.51', '158.99', '290.57']
# ....................................................................................................
# Episode 800 complete
# Learner:0	Reward total:32	Running mean: 30.82
# Learner:1	Reward total:29	Running mean: 21.03
# Learner:2	Reward total:108	Running mean: 109.2
# Learner:3	Reward total:9	Running mean: 9.559
# Learner:4	Reward total:68	Running mean: 78.48
# Learner:5	Reward total:20	Running mean: 32.7
# Learner:6	Reward total:24	Running mean: 36.38
# Learner:7	Reward total:134	Running mean: 92.25
# Max Norms =  ['132.81', '152.50', '243.22', '189.90', '275.70', '129.47', '141.63', '261.69']
# ....................................................................................................
# Episode 900 complete
# Learner:0	Reward total:18	Running mean: 27.98
# Learner:1	Reward total:7	Running mean: 19.0
# Learner:2	Reward total:108	Running mean: 127.9
# Learner:3	Reward total:24	Running mean: 13.57
# Learner:4	Reward total:65	Running mean: 75.31
# Learner:5	Reward total:46	Running mean: 31.02
# Learner:6	Reward total:44	Running mean: 32.32
# Learner:7	Reward total:88	Running mean: 85.02
# Max Norms =  ['298.07', '151.34', '206.61', '107.80', '264.57', '142.51', '166.94', '157.03']
# ....................................................................................................
# Episode 1000 complete
# Learner:0	Reward total:10	Running mean: 26.54
# Learner:1	Reward total:29	Running mean: 19.61
# Learner:2	Reward total:117	Running mean: 120.6
# Learner:3	Reward total:27	Running mean: 17.92
# Learner:4	Reward total:73	Running mean: 72.93
# Learner:5	Reward total:18	Running mean: 30.88
# Learner:6	Reward total:32	Running mean: 34.03
# Learner:7	Reward total:90	Running mean: 82.68
# Max Norms =  ['248.15', '72.15', '136.83', '88.27', '192.64', '132.67', '185.04', '218.15']
# ....................................................................................................
# Episode 1100 complete
# Learner:0	Reward total:30	Running mean: 27.77
# Learner:1	Reward total:21	Running mean: 20.69
# Learner:2	Reward total:125	Running mean: 124.1
# Learner:3	Reward total:12	Running mean: 20.35
# Learner:4	Reward total:69	Running mean: 81.77
# Learner:5	Reward total:26	Running mean: 31.27
# Learner:6	Reward total:27	Running mean: 36.83
# Learner:7	Reward total:122	Running mean: 80.11
# Max Norms =  ['251.03', '97.73', '284.52', '83.20', '344.39', '120.45', '106.05', '222.48']
# ....................................................................................................
# Episode 1200 complete
# Learner:0	Reward total:30	Running mean: 31.27
# Learner:1	Reward total:14	Running mean: 19.59
# Learner:2	Reward total:148	Running mean: 128.1
# Learner:3	Reward total:30	Running mean: 22.93
# Learner:4	Reward total:80	Running mean: 76.87
# Learner:5	Reward total:28	Running mean: 26.61
# Learner:6	Reward total:31	Running mean: 37.57
# Learner:7	Reward total:54	Running mean: 68.89
# Max Norms =  ['200.49', '96.71', '173.76', '92.91', '170.14', '126.05', '162.42', '187.62']
# ....................................................................................................
# Episode 1300 complete
# Learner:0	Reward total:41	Running mean: 34.85
# Learner:1	Reward total:26	Running mean: 20.93
# Learner:2	Reward total:107	Running mean: 129.9
# Learner:3	Reward total:28	Running mean: 24.85
# Learner:4	Reward total:86	Running mean: 79.02
# Learner:5	Reward total:22	Running mean: 27.71
# Learner:6	Reward total:13	Running mean: 35.53
# Learner:7	Reward total:90	Running mean: 74.07
# Max Norms =  ['339.73', '120.40', '252.73', '58.73', '217.70', '125.46', '224.22', '165.27']
# ....................................................................................................
# Episode 1400 complete
# Learner:0	Reward total:67	Running mean: 36.34
# Learner:1	Reward total:24	Running mean: 21.26
# Learner:2	Reward total:115	Running mean: 133.4
# Learner:3	Reward total:21	Running mean: 24.94
# Learner:4	Reward total:72	Running mean: 78.93
# Learner:5	Reward total:36	Running mean: 27.29
# Learner:6	Reward total:35	Running mean: 33.21
# Learner:7	Reward total:61	Running mean: 75.58
# Max Norms =  ['153.45', '276.96', '236.90', '102.74', '182.40', '107.50', '134.34', '222.77']
# ....................................................................................................
# Episode 1500 complete
# Learner:0	Reward total:41	Running mean: 33.39
# Learner:1	Reward total:23	Running mean: 22.03
# Learner:2	Reward total:149	Running mean: 137.2
# Learner:3	Reward total:27	Running mean: 25.8
# Learner:4	Reward total:70	Running mean: 81.67
# Learner:5	Reward total:40	Running mean: 27.88
# Learner:6	Reward total:32	Running mean: 33.05
# Learner:7	Reward total:38	Running mean: 67.4
# Max Norms =  ['211.14', '93.69', '376.36', '132.25', '282.21', '60.34', '159.22', '140.57']
# ....................................................................................................
# Episode 1600 complete
# Learner:0	Reward total:46	Running mean: 36.75
# Learner:1	Reward total:20	Running mean: 25.8
# Learner:2	Reward total:108	Running mean: 137.7
# Learner:3	Reward total:27	Running mean: 27.47
# Learner:4	Reward total:114	Running mean: 82.12
# Learner:5	Reward total:27	Running mean: 28.41
# Learner:6	Reward total:35	Running mean: 32.34
# Learner:7	Reward total:47	Running mean: 66.32
# Max Norms =  ['147.69', '143.09', '249.82', '141.56', '204.32', '104.90', '221.47', '133.31']
# ....................................................................................................
# Episode 1700 complete
# Learner:0	Reward total:28	Running mean: 32.93
# Learner:1	Reward total:27	Running mean: 25.65
# Learner:2	Reward total:89	Running mean: 119.5
# Learner:3	Reward total:37	Running mean: 35.42
# Learner:4	Reward total:51	Running mean: 73.05
# Learner:5	Reward total:30	Running mean: 25.44
# Learner:6	Reward total:32	Running mean: 30.06
# Learner:7	Reward total:26	Running mean: 55.83
# Max Norms =  ['525.13', '86.60', '217.90', '96.02', '303.26', '148.70', '192.70', '105.31']
# ....................................................................................................
# Episode 1800 complete
# Learner:0	Reward total:30	Running mean: 33.03
# Learner:1	Reward total:15	Running mean: 29.14
# Learner:2	Reward total:102	Running mean: 114.0
# Learner:3	Reward total:34	Running mean: 41.61
# Learner:4	Reward total:48	Running mean: 66.96
# Learner:5	Reward total:16	Running mean: 22.2
# Learner:6	Reward total:22	Running mean: 26.84
# Learner:7	Reward total:64	Running mean: 51.77
# Max Norms =  ['228.73', '78.49', '265.23', '126.98', '174.09', '158.04', '239.19', '139.34']
# ....................................................................................................
# Episode 1900 complete
# Learner:0	Reward total:27	Running mean: 32.13
# Learner:1	Reward total:23	Running mean: 24.67
# Learner:2	Reward total:91	Running mean: 116.0
# Learner:3	Reward total:52	Running mean: 40.57
# Learner:4	Reward total:91	Running mean: 68.43
# Learner:5	Reward total:20	Running mean: 25.14
# Learner:6	Reward total:15	Running mean: 24.82
# Learner:7	Reward total:23	Running mean: 47.25
# Max Norms =  ['363.37', '110.29', '282.23', '106.65', '192.69', '90.95', '99.39', '180.23']
# ....................................................................................................
# Episode 2000 complete
# Learner:0	Reward total:30	Running mean: 32.51
# Learner:1	Reward total:16	Running mean: 24.24
# Learner:2	Reward total:91	Running mean: 103.9
# Learner:3	Reward total:53	Running mean: 43.43
# Learner:4	Reward total:33	Running mean: 65.79
# Learner:5	Reward total:23	Running mean: 25.92
# Learner:6	Reward total:48	Running mean: 23.95
# Learner:7	Reward total:41	Running mean: 47.4
# Max Norms =  ['200.43', '140.87', '284.46', '127.41', '212.01', '246.73', '153.73', '159.40']
# ....................................................................................................
# Episode 2100 complete
# Learner:0	Reward total:20	Running mean: 33.52
# Learner:1	Reward total:35	Running mean: 22.84
# Learner:2	Reward total:142	Running mean: 112.8
# Learner:3	Reward total:31	Running mean: 40.98
# Learner:4	Reward total:76	Running mean: 62.4
# Learner:5	Reward total:19	Running mean: 24.08
# Learner:6	Reward total:16	Running mean: 21.55
# Learner:7	Reward total:58	Running mean: 42.61
# Max Norms =  ['162.95', '106.74', '229.86', '56.32', '189.92', '162.42', '108.60', '78.02']
# ....................................................................................................
# Episode 2200 complete
# Learner:0	Reward total:22	Running mean: 36.96
# Learner:1	Reward total:39	Running mean: 26.25
# Learner:2	Reward total:116	Running mean: 115.4
# Learner:3	Reward total:42	Running mean: 44.3
# Learner:4	Reward total:45	Running mean: 60.62
# Learner:5	Reward total:18	Running mean: 23.83
# Learner:6	Reward total:25	Running mean: 22.87
# Learner:7	Reward total:34	Running mean: 39.96
# Max Norms =  ['211.15', '83.60', '200.43', '82.87', '225.07', '122.61', '117.18', '166.72']
# ....................................................................................................
# Episode 2300 complete
# Learner:0	Reward total:52	Running mean: 34.8
# Learner:1	Reward total:26	Running mean: 26.39
# Learner:2	Reward total:126	Running mean: 116.6
# Learner:3	Reward total:55	Running mean: 45.17
# Learner:4	Reward total:71	Running mean: 63.83
# Learner:5	Reward total:13	Running mean: 23.23
# Learner:6	Reward total:6	Running mean: 22.79
# Learner:7	Reward total:17	Running mean: 32.41
# Max Norms =  ['170.83', '84.43', '292.92', '62.49', '287.78', '102.90', '178.67', '183.17']
# ....................................................................................................
# Episode 2400 complete
# Learner:0	Reward total:44	Running mean: 35.07
# Learner:1	Reward total:14	Running mean: 26.14
# Learner:2	Reward total:98	Running mean: 126.2
# Learner:3	Reward total:35	Running mean: 38.5
# Learner:4	Reward total:62	Running mean: 66.75
# Learner:5	Reward total:35	Running mean: 24.07
# Learner:6	Reward total:16	Running mean: 21.12
# Learner:7	Reward total:76	Running mean: 37.3
# Max Norms =  ['171.14', '136.17', '241.67', '83.50', '277.74', '169.47', '199.12', '160.83']
# ....................................................................................................
# Episode 2500 complete
# Learner:0	Reward total:29	Running mean: 34.69
# Learner:1	Reward total:25	Running mean: 27.9
# Learner:2	Reward total:79	Running mean: 118.2
# Learner:3	Reward total:34	Running mean: 40.74
# Learner:4	Reward total:42	Running mean: 70.43
# Learner:5	Reward total:32	Running mean: 22.13
# Learner:6	Reward total:16	Running mean: 19.68
# Learner:7	Reward total:42	Running mean: 37.96
# Max Norms =  ['149.27', '105.62', '200.16', '179.79', '157.74', '171.43', '134.00', '241.96']
# ....................................................................................................
# Episode 2600 complete
# Learner:0	Reward total:37	Running mean: 31.56
# Learner:1	Reward total:18	Running mean: 24.27
# Learner:2	Reward total:132	Running mean: 113.2
# Learner:3	Reward total:40	Running mean: 40.37
# Learner:4	Reward total:88	Running mean: 67.3
# Learner:5	Reward total:27	Running mean: 23.28
# Learner:6	Reward total:14	Running mean: 18.44
# Learner:7	Reward total:51	Running mean: 39.51
# Max Norms =  ['198.56', '55.99', '253.83', '115.76', '260.23', '115.59', '163.03', '177.13']
# ....................................................................................................
# Episode 2700 complete
# Learner:0	Reward total:24	Running mean: 34.37
# Learner:1	Reward total:27	Running mean: 29.1
# Learner:2	Reward total:111	Running mean: 110.9
# Learner:3	Reward total:69	Running mean: 44.87
# Learner:4	Reward total:53	Running mean: 64.91
# Learner:5	Reward total:29	Running mean: 21.09
# Learner:6	Reward total:16	Running mean: 19.41
# Learner:7	Reward total:14	Running mean: 38.34
# Max Norms =  ['169.30', '274.45', '243.83', '47.94', '148.45', '160.09', '166.13', '151.93']
# ....................................................................................................
# Episode 2800 complete
# Learner:0	Reward total:19	Running mean: 37.3
# Learner:1	Reward total:53	Running mean: 29.7
# Learner:2	Reward total:120	Running mean: 116.4
# Learner:3	Reward total:50	Running mean: 46.47
# Learner:4	Reward total:89	Running mean: 65.49
# Learner:5	Reward total:8	Running mean: 21.69
# Learner:6	Reward total:34	Running mean: 20.7
# Learner:7	Reward total:24	Running mean: 38.31
# Max Norms =  ['165.14', '230.95', '333.95', '169.35', '235.21', '197.27', '136.43', '92.77']
# ....................................................................................................
# Episode 2900 complete
# Learner:0	Reward total:42	Running mean: 37.15
# Learner:1	Reward total:8	Running mean: 23.01
# Learner:2	Reward total:187	Running mean: 124.4
# Learner:3	Reward total:54	Running mean: 44.17
# Learner:4	Reward total:21	Running mean: 65.84
# Learner:5	Reward total:13	Running mean: 18.7
# Learner:6	Reward total:24	Running mean: 20.39
# Learner:7	Reward total:15	Running mean: 37.41
# Max Norms =  ['193.68', '176.93', '311.30', '107.48', '121.27', '103.88', '178.87', '197.74']
# ....................................................................................................
# Episode 3000 complete
# Learner:0	Reward total:34	Running mean: 35.21
# Learner:1	Reward total:15	Running mean: 19.68
# Learner:2	Reward total:112	Running mean: 128.1
# Learner:3	Reward total:47	Running mean: 46.59
# Learner:4	Reward total:96	Running mean: 61.31
# Learner:5	Reward total:8	Running mean: 20.35
# Learner:6	Reward total:18	Running mean: 22.48
# Learner:7	Reward total:31	Running mean: 32.57
# Max Norms =  ['169.29', '178.36', '313.38', '135.38', '261.33', '131.17', '149.61', '129.51']
# ....................................................................................................
# Episode 3100 complete
# Learner:0	Reward total:22	Running mean: 28.37
# Learner:1	Reward total:18	Running mean: 16.93
# Learner:2	Reward total:116	Running mean: 130.3
# Learner:3	Reward total:59	Running mean: 43.07
# Learner:4	Reward total:46	Running mean: 65.69
# Learner:5	Reward total:3	Running mean: 18.62
# Learner:6	Reward total:25	Running mean: 20.54
# Learner:7	Reward total:35	Running mean: 27.34
# Max Norms =  ['119.02', '111.27', '211.79', '184.77', '208.85', '252.06', '116.40', '111.83']
# ....................................................................................................
# Episode 3200 complete
# Learner:0	Reward total:37	Running mean: 34.46
# Learner:1	Reward total:15	Running mean: 20.38
# Learner:2	Reward total:79	Running mean: 130.9
# Learner:3	Reward total:57	Running mean: 42.4
# Learner:4	Reward total:80	Running mean: 76.23
# Learner:5	Reward total:35	Running mean: 20.42
# Learner:6	Reward total:32	Running mean: 18.62
# ...
# Learner:4	Reward total:81	Running mean: 69.38
# Learner:5	Reward total:45	Running mean: 31.14
# Learner:6	Reward total:36	Running mean: 33.39
# Learner:7	Reward total:23	Running mean: 27.76
# Max Norms =  ['90.52', '226.02', '27.84', '188.34', '251.33', '155.93', '190.17', '160.04']
# ....................................................................................................
# Episode 2400 complete
# Learner:0	Reward total:33	Running mean: 24.07
# Learner:1	Reward total:115	Running mean: 135.0
# Learner:2	Reward total:8	Running mean: 16.47
# Learner:3	Reward total:16	Running mean: 50.64
# Learner:4	Reward total:80	Running mean: 72.38
# Learner:5	Reward total:51	Running mean: 38.25
# Learner:6	Reward total:44	Running mean: 26.0
# Learner:7	Reward total:61	Running mean: 31.43
# Max Norms =  ['78.56', '273.94', '55.09', '215.57', '242.72', '172.68', '98.94', '260.51']
# ....................................................................................................
# Episode 2500 complete
# Learner:0	Reward total:23	Running mean: 23.64
# Learner:1	Reward total:111	Running mean: 147.8
# Learner:2	Reward total:19	Running mean: 16.93
# Learner:3	Reward total:98	Running mean: 56.07
# Learner:4	Reward total:33	Running mean: 62.69
# Learner:5	Reward total:83	Running mean: 45.32
# Learner:6	Reward total:33	Running mean: 31.92
# Learner:7	Reward total:33	Running mean: 32.14
# Max Norms =  ['141.19', '209.19', '70.09', '183.91', '189.45', '153.51', '166.67', '117.85']
# ....................................................................................................
# Episode 2600 complete
# Learner:0	Reward total:3	Running mean: 21.2
# Learner:1	Reward total:133	Running mean: 150.6
# Learner:2	Reward total:8	Running mean: 14.93
# Learner:3	Reward total:16	Running mean: 54.63
# Learner:4	Reward total:28	Running mean: 53.29
# Learner:5	Reward total:26	Running mean: 46.27
# Learner:6	Reward total:120	Running mean: 36.64
# Learner:7	Reward total:10	Running mean: 30.27
# Max Norms =  ['173.62', '414.35', '60.82', '192.86', '174.79', '197.75', '183.61', '95.40']
# ....................................................................................................
# Episode 2700 complete
# Learner:0	Reward total:9	Running mean: 17.9
# Learner:1	Reward total:171	Running mean: 134.7
# Learner:2	Reward total:20	Running mean: 15.22
# Learner:3	Reward total:39	Running mean: 41.54
# Learner:4	Reward total:11	Running mean: 47.29
# Learner:5	Reward total:33	Running mean: 47.0
# Learner:6	Reward total:39	Running mean: 61.57
# Learner:7	Reward total:57	Running mean: 27.52
# Max Norms =  ['96.46', '352.91', '48.59', '164.37', '199.06', '135.00', '209.63', '289.78']
# ....................................................................................................
# Episode 2800 complete
# Learner:0	Reward total:11	Running mean: 14.67
# Learner:1	Reward total:215	Running mean: 117.1
# Learner:2	Reward total:13	Running mean: 14.97
# Learner:3	Reward total:53	Running mean: 40.92
# Learner:4	Reward total:46	Running mean: 49.79
# Learner:5	Reward total:11	Running mean: 45.13
# Learner:6	Reward total:26	Running mean: 71.66
# Learner:7	Reward total:42	Running mean: 28.29
# Max Norms =  ['64.18', '277.72', '43.93', '187.24', '198.95', '145.11', '122.79', '178.39']
# ....................................................................................................
# Episode 2900 complete
# Learner:0	Reward total:16	Running mean: 14.06
# Learner:1	Reward total:89	Running mean: 115.5
# Learner:2	Reward total:16	Running mean: 14.73
# Learner:3	Reward total:41	Running mean: 38.27
# Learner:4	Reward total:108	Running mean: 62.28
# Learner:5	Reward total:27	Running mean: 45.86
# Learner:6	Reward total:18	Running mean: 50.55
# Learner:7	Reward total:25	Running mean: 26.71
# Max Norms =  ['111.37', '347.10', '48.22', '200.48', '291.50', '417.25', '74.97', '101.40']
# ....................................................................................................
# Episode 3000 complete
# Learner:0	Reward total:6	Running mean: 13.51
# Learner:1	Reward total:210	Running mean: 115.4
# Learner:2	Reward total:7	Running mean: 13.39
# Learner:3	Reward total:25	Running mean: 31.97
# Learner:4	Reward total:7	Running mean: 52.25
# Learner:5	Reward total:26	Running mean: 39.6
# Learner:6	Reward total:68	Running mean: 44.78
# Learner:7	Reward total:22	Running mean: 25.61
# Max Norms =  ['17.09', '340.06', '9.13', '377.26', '281.10', '192.14', '241.37', '45.75']
# ....................................................................................................
# Episode 3100 complete
# Learner:0	Reward total:25	Running mean: 21.05
# Learner:1	Reward total:73	Running mean: 121.4
# Learner:2	Reward total:16	Running mean: 17.0
# Learner:3	Reward total:34	Running mean: 37.55
# Learner:4	Reward total:63	Running mean: 61.48
# Learner:5	Reward total:95	Running mean: 44.16
# Learner:6	Reward total:59	Running mean: 36.38
# Learner:7	Reward total:34	Running mean: 27.9
# Max Norms =  ['43.34', '299.92', '59.95', '260.55', '225.02', '145.56', '142.13', '95.78']
# ....................................................................................................
# Episode 3200 complete
# Learner:0	Reward total:11	Running mean: 19.26
# Learner:1	Reward total:191	Running mean: 108.9
# Learner:2	Reward total:13	Running mean: 19.05
# Learner:3	Reward total:44	Running mean: 42.16
# Learner:4	Reward total:36	Running mean: 73.6
# Learner:5	Reward total:20	Running mean: 45.22
# Learner:6	Reward total:14	Running mean: 32.16
# Learner:7	Reward total:27	Running mean: 31.49
# Max Norms =  ['28.46', '251.77', '24.43', '101.08', '242.51', '105.75', '75.52', '95.31']
# ....................................................................................................
# Episode 3300 complete
# Learner:0	Reward total:20	Running mean: 18.63
# Learner:1	Reward total:143	Running mean: 116.6
# Learner:2	Reward total:31	Running mean: 20.93
# Learner:3	Reward total:42	Running mean: 44.76
# Learner:4	Reward total:65	Running mean: 70.73
# Learner:5	Reward total:41	Running mean: 45.48
# Learner:6	Reward total:11	Running mean: 23.24
# Learner:7	Reward total:26	Running mean: 31.46
# Max Norms =  ['104.54', '294.62', '99.73', '175.54', '230.87', '127.73', '69.26', '124.78']
# ....................................................................................................
# Episode 3400 complete
# Learner:0	Reward total:5	Running mean: 18.5
# Learner:1	Reward total:114	Running mean: 128.8
# Learner:2	Reward total:15	Running mean: 21.48
# Learner:3	Reward total:84	Running mean: 50.71
# Learner:4	Reward total:38	Running mean: 64.49
# Learner:5	Reward total:81	Running mean: 47.11
# Learner:6	Reward total:20	Running mean: 19.92
# Learner:7	Reward total:22	Running mean: 32.21
# Max Norms =  ['106.24', '289.14', '52.24', '127.64', '285.55', '173.75', '69.25', '208.66']
# ....................................................................................................
# Episode 3500 complete
# Learner:0	Reward total:16	Running mean: 18.01
# Learner:1	Reward total:172	Running mean: 134.6
# Learner:2	Reward total:18	Running mean: 20.02
# Learner:3	Reward total:53	Running mean: 54.6
# Learner:4	Reward total:66	Running mean: 60.18
# Learner:5	Reward total:39	Running mean: 46.43
# Learner:6	Reward total:44	Running mean: 20.37
# Learner:7	Reward total:26	Running mean: 31.16
# Max Norms =  ['139.58', '238.16', '33.41', '162.10', '242.07', '124.71', '77.65', '67.29']
# ....................................................................................................
# Episode 3600 complete
# Learner:0	Reward total:11	Running mean: 21.02
# Learner:1	Reward total:122	Running mean: 135.8
# Learner:2	Reward total:11	Running mean: 21.99
# Learner:3	Reward total:24	Running mean: 55.09
# Learner:4	Reward total:71	Running mean: 62.39
# Learner:5	Reward total:69	Running mean: 50.36
# Learner:6	Reward total:24	Running mean: 18.32
# Learner:7	Reward total:48	Running mean: 35.72
# Max Norms =  ['161.72', '266.33', '50.11', '184.56', '236.25', '133.27', '80.26', '162.50']
# ....................................................................................................
# Episode 3700 complete
# Learner:0	Reward total:28	Running mean: 19.96
# Learner:1	Reward total:89	Running mean: 130.1
# Learner:2	Reward total:38	Running mean: 21.46
# Learner:3	Reward total:12	Running mean: 54.14
# Learner:4	Reward total:77	Running mean: 67.88
# Learner:5	Reward total:45	Running mean: 54.3
# Learner:6	Reward total:5	Running mean: 17.78
# Learner:7	Reward total:39	Running mean: 36.63
# Max Norms =  ['84.65', '285.95', '45.52', '214.98', '441.29', '120.21', '51.79', '133.37']
# ....................................................................................................
# Episode 3800 complete
# Learner:0	Reward total:4	Running mean: 18.53
# Learner:1	Reward total:121	Running mean: 116.9
# Learner:2	Reward total:14	Running mean: 21.78
# Learner:3	Reward total:68	Running mean: 59.83
# Learner:4	Reward total:68	Running mean: 76.62
# Learner:5	Reward total:52	Running mean: 51.63
# Learner:6	Reward total:22	Running mean: 19.51
# Learner:7	Reward total:26	Running mean: 34.73
# Max Norms =  ['129.77', '223.08', '64.24', '186.38', '375.63', '311.36', '98.12', '107.70']
# ....................................................................................................
# Episode 3900 complete
# Learner:0	Reward total:25	Running mean: 17.14
# Learner:1	Reward total:125	Running mean: 110.0
# Learner:2	Reward total:14	Running mean: 19.91
# Learner:3	Reward total:42	Running mean: 51.64
# Learner:4	Reward total:84	Running mean: 80.47
# Learner:5	Reward total:34	Running mean: 58.07
# Learner:6	Reward total:15	Running mean: 18.15
# Learner:7	Reward total:25	Running mean: 34.89
# Max Norms =  ['133.37', '283.38', '118.60', '135.72', '252.66', '290.53', '47.81', '162.58']
# ....................................................................................................
# Episode 4000 complete
# Learner:0	Reward total:21	Running mean: 17.26
# Learner:1	Reward total:77	Running mean: 113.3
# Learner:2	Reward total:30	Running mean: 20.37
# Learner:3	Reward total:63	Running mean: 53.52
# Learner:4	Reward total:59	Running mean: 76.99
# Learner:5	Reward total:96	Running mean: 61.94
# Learner:6	Reward total:12	Running mean: 17.95
# Learner:7	Reward total:44	Running mean: 35.76
# Max Norms =  ['51.03', '188.83', '100.69', '165.96', '449.59', '254.97', '172.40', '190.94']
# ....................................................................................................
# Episode 4100 complete
# Learner:0	Reward total:27	Running mean: 16.18
# Learner:1	Reward total:137	Running mean: 115.5
# Learner:2	Reward total:8	Running mean: 18.9
# Learner:3	Reward total:20	Running mean: 43.2
# Learner:4	Reward total:82	Running mean: 75.97
# Learner:5	Reward total:62	Running mean: 62.26
# Learner:6	Reward total:24	Running mean: 19.76
# Learner:7	Reward total:16	Running mean: 32.85
# Max Norms =  ['81.92', '323.02', '27.92', '80.56', '346.64', '241.64', '89.52', '67.31']
# ....................................................................................................
# Episode 4200 complete
# Learner:0	Reward total:13	Running mean: 15.01
# Learner:1	Reward total:64	Running mean: 126.1
# Learner:2	Reward total:17	Running mean: 18.16
# Learner:3	Reward total:72	Running mean: 50.75
# Learner:4	Reward total:68	Running mean: 63.42
# Learner:5	Reward total:86	Running mean: 64.18
# Learner:6	Reward total:42	Running mean: 18.49
# Learner:7	Reward total:37	Running mean: 31.08
# Max Norms =  ['69.45', '338.78', '167.31', '117.97', '360.49', '200.95', '125.06', '93.80']
# ....................................................................................................
# Episode 4300 complete
# Learner:0	Reward total:13	Running mean: 14.93
# Learner:1	Reward total:152	Running mean: 130.2
# Learner:2	Reward total:9	Running mean: 17.73
# Learner:3	Reward total:74	Running mean: 48.11
# Learner:4	Reward total:65	Running mean: 61.41
# Learner:5	Reward total:59	Running mean: 70.18
# Learner:6	Reward total:23	Running mean: 21.15
# Learner:7	Reward total:25	Running mean: 32.89
# Max Norms =  ['98.00', '306.01', '78.80', '151.68', '232.79', '289.98', '162.30', '93.40']
# ....................................................................................................
# Episode 4400 complete
# Learner:0	Reward total:6	Running mean: 16.34
# Learner:1	Reward total:82	Running mean: 128.9
# Learner:2	Reward total:21	Running mean: 20.57
# Learner:3	Reward total:57	Running mean: 48.13
# Learner:4	Reward total:42	Running mean: 59.32
# Learner:5	Reward total:54	Running mean: 54.6
# Learner:6	Reward total:7	Running mean: 18.14
# Learner:7	Reward total:28	Running mean: 32.31
# Max Norms =  ['141.20', '335.43', '29.11', '79.12', '224.88', '161.99', '111.53', '72.18']
# ....................................................................................................
# Episode 4500 complete
# Learner:0	Reward total:16	Running mean: 19.78
# Learner:1	Reward total:113	Running mean: 112.8
# Learner:2	Reward total:31	Running mean: 23.76
# Learner:3	Reward total:49	Running mean: 62.55
# Learner:4	Reward total:61	Running mean: 58.56
# Learner:5	Reward total:66	Running mean: 62.97
# Learner:6	Reward total:25	Running mean: 23.18
# Learner:7	Reward total:53	Running mean: 33.65
# Max Norms =  ['71.21', '376.69', '53.90', '181.90', '430.64', '172.63', '197.64', '105.20']
# ....................................................................................................
# Episode 4600 complete
# Learner:0	Reward total:5	Running mean: 19.35
# Learner:1	Reward total:88	Running mean: 100.3
# Learner:2	Reward total:27	Running mean: 24.78
# Learner:3	Reward total:47	Running mean: 58.76
# Learner:4	Reward total:100	Running mean: 69.17
# Learner:5	Reward total:81	Running mean: 61.49
# Learner:6	Reward total:17	Running mean: 21.65
# Learner:7	Reward total:12	Running mean: 34.53
# Max Norms =  ['214.27', '210.43', '90.62', '162.42', '302.76', '101.96', '54.59', '156.48']
# ....................................................................................................
# Episode 4700 complete
# Learner:0	Reward total:15	Running mean: 19.49
# Learner:1	Reward total:73	Running mean: 91.28
# Learner:2	Reward total:10	Running mean: 22.67
# Learner:3	Reward total:86	Running mean: 55.45
# Learner:4	Reward total:82	Running mean: 81.88
# Learner:5	Reward total:74	Running mean: 68.17
# Learner:6	Reward total:12	Running mean: 21.25
# Learner:7	Reward total:45	Running mean: 36.56
# Max Norms =  ['146.17', '256.73', '72.77', '231.36', '343.57', '194.30', '147.40', '75.17']
# ....................................................................................................
# Episode 4800 complete
# Learner:0	Reward total:22	Running mean: 18.15
# Learner:1	Reward total:66	Running mean: 87.12
# Learner:2	Reward total:19	Running mean: 21.61
# Learner:3	Reward total:53	Running mean: 49.73
# Learner:4	Reward total:124	Running mean: 95.59
# Learner:5	Reward total:48	Running mean: 69.82
# Learner:6	Reward total:10	Running mean: 18.7
# Learner:7	Reward total:45	Running mean: 37.48
# Max Norms =  ['85.96', '297.43', '92.80', '217.06', '261.91', '187.00', '68.63', '81.00']
# ....................................................................................................
# Episode 4900 complete
# Learner:0	Reward total:20	Running mean: 18.19
# Learner:1	Reward total:56	Running mean: 79.03
# Learner:2	Reward total:22	Running mean: 22.93
# Learner:3	Reward total:65	Running mean: 51.8
# Learner:4	Reward total:152	Running mean: 96.56
# Learner:5	Reward total:39	Running mean: 68.17
# Learner:6	Reward total:15	Running mean: 15.88
# Learner:7	Reward total:34	Running mean: 36.77
# Max Norms =  ['84.02', '336.55', '91.32', '258.51', '380.99', '251.03', '85.05', '209.22']
# ....................................................................................................
# Episode 5000 complete
# Learner:0	Reward total:16	Running mean: 18.47
# Learner:1	Reward total:83	Running mean: 86.49
# Learner:2	Reward total:8	Running mean: 23.25
# Learner:3	Reward total:40	Running mean: 51.24
# Learner:4	Reward total:62	Running mean: 97.35
# Learner:5	Reward total:120	Running mean: 72.13
# Learner:6	Reward total:17	Running mean: 15.66
# Learner:7	Reward total:17	Running mean: 31.34
# Max Norms =  ['96.63', '758.82', '16.85', '167.01', '167.61', '137.47', '100.53', '111.61']

# %%
game = 'Gathering'

dir_names = ["results/warlike/p-1.0_r0.001/",
             "results/warlike-01/p-1.0_r0.005/",  # trained to 5000 episodes
             "results/warlike-01/p-1.0_r0.01/",   # trained to 5000 episodes
             "results/warlike-01/p-1.0_r0.05/",   # trained to 5000 episodes
             "results/warlike/p-1.0_r0.1/",
             "results/warlike/p-1.0_r0.5/",
             "results/warlike/p-1.0_r1.0/"]

num_learners = 8
num_tribes = 3

for dir_name in dir_names:
    print (dir_name)
    data = [[] for i in range(num_learners)]
    tribe_data = [[] for i in range(num_tribes)]

    # Load rewards
    for i in range(num_learners):
        data_file = dir_name+'MA{}_Gather.p'.format(i, game)
        with open(data_file, 'rb') as f:
            data[i] = pickle.load(f)

    total = [sum(x) for x in zip(*data)]

    for i in range(num_learners):
        print('Max. Running Reward - MA{} Ind Reward: {:.3f}'.format(i, max(data[i])))

    
    print('Max. Running Reward - All Agents: {:.3f}'.format(max(total)))

    tribe_data[0] = [sum(x) for x in zip(data[0],data[1],data[2])]
    tribe_data[1] = [sum(x) for x in zip(data[3],data[4])]
    tribe_data[2] = [sum(x) for x in zip(data[5],data[6],data[7])]

    for i in range(num_tribes):
        print('Tribe {} Sum Reward: {:.3f}'.format(i, max(tribe_data[i])))
    
    print ('\n')

    plt.figure(figsize=(10, 7))
    plt.plot(total, label='Total Rewards', color='green')
    for i in range(num_learners):
        plt.plot(data[i], label='MA{}_CNN Indv'.format(i), color=agent_colors[i])

    plt.title('{} Agent Rewards versus Episodes'.format(game))
    plt.xlabel('Episodes')
    plt.ylabel('Average Rewards')
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# results/warlike/p-1.0_r0.001/
# Max. Running Reward - MA0 Ind Reward: 0.211
# Max. Running Reward - MA1 Ind Reward: 20.147
# Max. Running Reward - MA2 Ind Reward: 46.687
# Max. Running Reward - MA3 Ind Reward: 23.328
# Max. Running Reward - MA4 Ind Reward: 62.525
# Max. Running Reward - MA5 Ind Reward: 1.137
# Max. Running Reward - MA6 Ind Reward: 141.490
# Max. Running Reward - MA7 Ind Reward: 224.780
# Max. Running Reward - All Agents: 385.520
# Tribe 0 Sum Reward: 65.997
# Tribe 1 Sum Reward: 83.695
# Tribe 2 Sum Reward: 328.942
# results/warlike-01/p-1.0_r0.005/
# Max. Running Reward - MA0 Ind Reward: 31.162
# Max. Running Reward - MA1 Ind Reward: 35.094
# Max. Running Reward - MA2 Ind Reward: 65.069
# Max. Running Reward - MA3 Ind Reward: 93.815
# Max. Running Reward - MA4 Ind Reward: 70.756
# Max. Running Reward - MA5 Ind Reward: 19.765
# Max. Running Reward - MA6 Ind Reward: 186.372
# Max. Running Reward - MA7 Ind Reward: 144.059
# Max. Running Reward - All Agents: 453.455
# Tribe 0 Sum Reward: 95.962
# Tribe 1 Sum Reward: 148.749
# Tribe 2 Sum Reward: 282.035
# results/warlike-01/p-1.0_r0.01/
# Max. Running Reward - MA0 Ind Reward: 55.410
# Max. Running Reward - MA1 Ind Reward: 35.292
# Max. Running Reward - MA2 Ind Reward: 139.510
# Max. Running Reward - MA3 Ind Reward: 51.132
# Max. Running Reward - MA4 Ind Reward: 110.948
# Max. Running Reward - MA5 Ind Reward: 54.967
# Max. Running Reward - MA6 Ind Reward: 69.850
# Max. Running Reward - MA7 Ind Reward: 101.841
# Max. Running Reward - All Agents: 437.258
# Tribe 0 Sum Reward: 207.455
# Tribe 1 Sum Reward: 129.565
# Tribe 2 Sum Reward: 211.144
# results/warlike-01/p-1.0_r0.05/
# Max. Running Reward - MA0 Ind Reward: 28.275
# Max. Running Reward - MA1 Ind Reward: 156.951
# Max. Running Reward - MA2 Ind Reward: 41.035
# Max. Running Reward - MA3 Ind Reward: 65.411
# Max. Running Reward - MA4 Ind Reward: 116.753
# Max. Running Reward - MA5 Ind Reward: 72.127
# Max. Running Reward - MA6 Ind Reward: 79.112
# Max. Running Reward - MA7 Ind Reward: 38.658
# Max. Running Reward - All Agents: 422.706
# Tribe 0 Sum Reward: 196.254
# Tribe 1 Sum Reward: 164.541
# Tribe 2 Sum Reward: 155.462
# results/warlike/p-1.0_r0.1/
# Max. Running Reward - MA0 Ind Reward: 40.015
# Max. Running Reward - MA1 Ind Reward: 31.009
# Max. Running Reward - MA2 Ind Reward: 91.506
# Max. Running Reward - MA3 Ind Reward: 27.012
# Max. Running Reward - MA4 Ind Reward: 101.251
# Max. Running Reward - MA5 Ind Reward: 65.966
# Max. Running Reward - MA6 Ind Reward: 27.843
# Max. Running Reward - MA7 Ind Reward: 87.807
# Max. Running Reward - All Agents: 374.727
# Tribe 0 Sum Reward: 154.699
# Tribe 1 Sum Reward: 107.617
# Tribe 2 Sum Reward: 163.123
# results/warlike/p-1.0_r0.5/
# Max. Running Reward - MA0 Ind Reward: 0.391
# Max. Running Reward - MA1 Ind Reward: 0.000
# Max. Running Reward - MA2 Ind Reward: 0.000
# Max. Running Reward - MA3 Ind Reward: 0.060
# Max. Running Reward - MA4 Ind Reward: 0.050
# Max. Running Reward - MA5 Ind Reward: 0.194
# Max. Running Reward - MA6 Ind Reward: 0.110
# Max. Running Reward - MA7 Ind Reward: 4.220
# Max. Running Reward - All Agents: 4.737
# Tribe 0 Sum Reward: 0.391
# Tribe 1 Sum Reward: 0.081
# Tribe 2 Sum Reward: 4.335
# results/warlike/p-1.0_r1.0/
# Max. Running Reward - MA0 Ind Reward: 0.010
# Max. Running Reward - MA1 Ind Reward: 0.000
# Max. Running Reward - MA2 Ind Reward: 0.000
# Max. Running Reward - MA3 Ind Reward: 0.000
# Max. Running Reward - MA4 Ind Reward: 0.010
# Max. Running Reward - MA5 Ind Reward: 0.101
# Max. Running Reward - MA6 Ind Reward: 0.136
# Max. Running Reward - MA7 Ind Reward: 0.326
# Max. Running Reward - All Agents: 0.525
# Tribe 0 Sum Reward: 0.010
# Tribe 1 Sum Reward: 0.010
# Tribe 2 Sum Reward: 0.519
